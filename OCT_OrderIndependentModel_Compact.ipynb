# %%
# Parameters
fold = 1
dataset = 'monks-1'
D = 2
d = 2
trace = 0

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Nov 18 22:11:32 2023

@author: khaniyev
"""

#%%

import gurobipy as gp
import gurobipy
import pandas as pd
import numpy as np
import time

# %%
import numpy as np
from typing import List, Tuple

def get_split_values(leaf_type: int, depth: int) -> np.ndarray:
    """
    Compute the binary split pattern for a given leaf_type over a tree of given depth.
    Returns an array of 0.0/1.0 of length `depth`, where each entry is 1.0−bit of leaf_type.
    """
    bits = np.empty(depth, dtype=float)
    rem_val = leaf_type
    for l in range(depth):
        power = 2 ** (depth - l - 1)
        bits[l] = rem_val // power
        rem_val -= int(bits[l] * power)
    # invert so that 0→1.0 and 1→0.0 matches the Cython version
    return 1.0 - bits


def get_misclassification_bag(
    x: np.ndarray,
    y_k: np.ndarray,
    leaf_pattern: Tuple[List[int], List[int]],
    leaf_type: int
) -> Tuple[float, int, np.ndarray]:
    """
    Mask off the rows of x/y_k according to the leaf_pattern and leaf_type,
    then compute the misclassification count and sample size.

    Parameters
    ----------
    x : array of shape (N, p)
        Binary feature matrix (values 0 or 1).
    y_k : array of shape (N, C)
        One-hot (or count) matrix of class labels.
    leaf_pattern : (pattern0, pattern1)
        A tuple of two lists of feature-indices: 
        - pattern0 = features to test when split_value==0
        - pattern1 = features to test when split_value==1
    leaf_type : int
        An integer in [0, 2**depth − 1] indicating the leaf.

    Returns
    -------
    misclassification : float
        Number of misclassified samples = num_samples − max_class_count.
    num_samples : int
        Total number of samples reaching this leaf.
    mask : ndarray of bool, shape (N,)
        Boolean mask indicating which rows were selected.
    """
    # total depth is sum of lengths of both patterns
    depth = len(leaf_pattern[0]) + len(leaf_pattern[1])
    split_values = get_split_values(leaf_type, depth)

    # start with all True
    mask = np.ones(x.shape[0], dtype=bool)

    # for each unique split (0.0 or 1.0), refine mask by enforcing all features in the corresponding pattern
    for split in set(split_values):
        split_int = int(split)
        for feat in leaf_pattern[1 - split_int]:
            mask &= (x[:, feat] == split)

    # filter
    y_filt = y_k[mask]
    num_samples = y_filt.shape[0]

    if num_samples > 0:
        # count per class, take the largest
        class_counts = np.sum(y_filt, axis=0)
        max_class_sum = np.max(class_counts)
        misclassification = float(num_samples - max_class_sum)
    else:
        misclassification = 0.0

    return misclassification, num_samples, mask

# %% [markdown]
# loop

# %%
relpath="./Datasets/"+dataset+"/fold="+str(fold)+"_train.csv"
data = pd.read_csv(relpath)#pd.read_csv("./Datasets/fold=1_train.csv")

X = data.iloc[:,1:]
y = data.iloc[:,:1]
PP = [i for i in range(data.shape[1]-1)]
P = len(PP)
KK = list(data.y.unique())
K = len(KK)
D = d # depth
DD = list(range(D))
L = 2**D
LL = list(range(L))
NN = list(range(X.shape[0]))
N = len(NN)
y_k = np.zeros((X.shape[0], K))
for k in range(K):
    y_k[np.where(y==KK[k])[0],k] = 1

y_k= y_k.astype(np.int32)

x = np.array(X,dtype=np.int32)



relpath="./Datasets/"+dataset+"/fold="+str(fold)+"_test.csv"
data_test = pd.read_csv(relpath)#pd.read_csv("./Datasets/fold=1_train.csv")

X_test = data_test.iloc[:,1:]
y_test = data_test.iloc[:,:1]

y_k_test = np.zeros((X_test.shape[0], K))
for k in range(K):
    y_k_test[np.where(y_test==KK[k])[0],k] = 1

y_k_test=y_k_test.astype(np.int32)
x_test = np.array(X_test,dtype=np.int32)





relpath="./Datasets/"+dataset+"/fold="+str(fold)

# %%
def get_patterns(model,D,P):
    patterns_all=[]

    for leaf in range(2**D):
        node_splits=np.where(model.X[:(2**D-1)*P])  # should return 2**D-1 many
        node_splits_features_features=np.array(node_splits).flatten()//(2**D-1)
        node_splits_features_order=np.array(node_splits).flatten()%(2**D-1)

        # Get the indices that would sort the order_array
        sorted_indices = np.argsort(node_splits_features_order)
        node_splits_features=node_splits_features_features[sorted_indices]



        split_values=1-get_split_values(leaf,d).astype(int)
        w_indices_for_leaf=[0]

        ### obtain the leaf's association with split nodes
        for d_temp in range(1,d):
            values=np.arange(2**d_temp -1,2**d_temp -1 + 2**d_temp)
            w_index=leaf//(2**(d-d_temp))
            w_indices_for_leaf.append(values[w_index])


        pattern=[[],[]]

        for d_ in range(D):
            value=split_values[d_]
            w_index=w_indices_for_leaf[d_]
            pattern[value].append(node_splits_features[w_index])
        
        patterns_all.append(tuple(pattern))

    return patterns_all

def get_tree_mis(inc_patterns,d,x,y_k):
    miss=0
    for leaf in range(2**d):
        miss+=get_misclassification_bag(x, y_k, inc_patterns[leaf], leaf)[0]
    return miss/len(x)

# %%
    model_compact = gp.Model("OrderIndependentCompact")
    model_compact.setParam("OutputFlag", 1)
    model_compact.setParam('TimeLimit', 3600)
    
    z = model_compact.addVars(P, 2**d-1, vtype=gp.GRB.BINARY, name='node')
    a = model_compact.addVars(P, L, vtype=gp.GRB.BINARY, name='a')
    b = model_compact.addVars(P, L, vtype=gp.GRB.BINARY, name='b')
    t = model_compact.addVars(N, L, vtype=gp.GRB.CONTINUOUS, ub=1, name='t')
    c = model_compact.addVars(K, L, vtype=gp.GRB.BINARY, name='c')
    
    # objective: minimize misclassification error
    misclassification_error = gp.LinExpr((1/N)*gp.quicksum(t[i,l] for i in range(N) for l in range(L)))
    model_compact.setObjective(misclassification_error, gp.GRB.MINIMIZE)
    
    # Exactly one feature selected per internal node
    model_compact.addConstrs(gp.quicksum(z[j,branch] for j in range(P)) == 1 for branch in range(2**d-1)) 
    
    for l in range(L):
        # Determine path nodes and branches for leaf l
        # Node indices follow standard binary tree: root=0, children of v are 2v+1, 2v+2
        path_nodes = []
        branch_types = [] # 0 for left (expect x=0), 1 for right (expect x=1)
        curr = 0
        for depth_step in range(d):
            bit = (l >> (d - 1 - depth_step)) & 1
            path_nodes.append(curr)
            branch_types.append(bit)
            curr = 2 * curr + (bit + 1)
            
        # Misclassification (t) constraints
        for i in range(N):
            # Penalty if x[i,j] != expected branch value for selected feature j
            expr = gp.quicksum(
                (x[i,j] if branch_types[step] == 0 else (1 - x[i,j])) * z[j, path_nodes[step]]
                for step in range(d) for j in range(P)
            )
            model_compact.addConstr(t[i,l] >= expr - gp.quicksum(y_k[i,k]*c[k,l] for k in range(K)) - (d-1))
            
        # a[j,l]/b[j,l] collect features on path with left/right branches respectively
        left_nodes = [path_nodes[step] for step in range(d) if branch_types[step] == 0]
        right_nodes = [path_nodes[step] for step in range(d) if branch_types[step] == 1]
        
        if left_nodes:
            model_compact.addConstrs(gp.quicksum(z[j, n_idx] for n_idx in left_nodes) == a[j,l] for j in range(P))
        else:
            model_compact.addConstrs(a[j,l] == 0 for j in range(P))
            
        if right_nodes:
            model_compact.addConstrs(gp.quicksum(z[j, n_idx] for n_idx in right_nodes) == b[j,l] for j in range(P))
        else:
            model_compact.addConstrs(b[j,l] == 0 for j in range(P))
            
        # Path cardinality checks (though implied by equalities above)
        model_compact.addConstr(gp.quicksum(a[j,l] for j in range(P)) == len(left_nodes))
        model_compact.addConstr(gp.quicksum(b[j,l] for j in range(P)) == len(right_nodes))

    # one leaf-classifier per leaf
    model_compact.addConstrs(gp.quicksum(c[k,l] for k in range(K)) == 1 for l in range(L)) 
    
    model_compact.update()
    start_time=time.time()
    opt_sol = model_compact.optimize()
    end_time=time.time()
    
    # Predict on test set
    inc_patterns=get_patterns(model_compact,D,P)
    miss_test=get_tree_mis(inc_patterns,d,x_test,y_k_test)
 
    # Combine results and save
    res = np.array([1-model_compact.objval, 1-miss_test, end_time-start_time, model_compact.MIPGap])
    res = np.reshape(res,(4,1))
    np.savetxt(relpath+'_resCompactOrderIndependent_'+str(d)+'.txt', res, fmt='%.6f')
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-26
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.2.0 24C101)
#
# CPU model: Apple M3 Pro
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
#
# Optimize a model with 2105 rows, 2173 columns and 34383 nonzeros
# Model fingerprint: 0xc659d481
# Variable types: 2000 continuous, 173 integer (173 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-03, 2e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Found heuristic solution: objective 0.4960000
# Presolve removed 462 rows and 486 columns
# Presolve time: 0.01s
# Presolved: 1643 rows, 1687 columns, 21471 nonzeros
# Variable types: 1608 continuous, 79 integer (79 binary)
#
# Root relaxation: objective 0.000000e+00, 103 iterations, 0.00 seconds (0.01 work units)
#
# ...

# %%
import sys

orig_stdout = sys.stdout
f = open(relpath+'_DecisionRules_Compact_'+str(d)+'.txt', 'w')
sys.stdout = f


def format_rules(patterns):
    lines = []
    def to_native(obj):
        if isinstance(obj, (list, tuple)):
            return type(obj)(to_native(x) for x in obj)
        if hasattr(obj, 'item'):
            return obj.item()
        return obj
    native_patterns = to_native(patterns)
    import numpy as np
    global_P = globals().get('P', globals().get('p', None))
    global_D = globals().get('D', globals().get('d', None))
    model_types = [
        globals().get('model_compact', None),
        (globals().get('IP_model', [None])[0] if 'IP_model' in globals() and isinstance(globals()['IP_model'], list) else None),
        (globals().get('inc_node', None).IP if globals().get('inc_node', None) and hasattr(globals().get('inc_node', None), 'IP') else None),
    ]
    model_obj = next((m for m in model_types if m is not None and hasattr(m, 'X')), None)
    
    tree_lines = []
    if model_obj and global_P is not None and global_D is not None:
        try:
            L_vars = (2**global_D - 1) * global_P
            node_splits = np.where(np.array(model_obj.X[:L_vars]) > 0.5)
            node_feat = np.array(node_splits).flatten() // (2**global_D - 1)
            node_ord = np.array(node_splits).flatten() % (2**global_D - 1)
            node_splits_features = node_feat[np.argsort(node_ord)]
            tree_lines.append('\n--- Reconstructed Split Tree ---')
            def traverse(node_idx, depth, prefix=''):
                if depth == global_D: return
                feature = node_splits_features[node_idx]
                tree_lines.append(f'{prefix}Node {node_idx} -> Split on Feature {feature}')
                left, right = 2 * node_idx + 1, 2 * node_idx + 2
                offset = 2**global_D - 1
                if depth < global_D - 1:
                    tree_lines.append(f'{prefix}  |-- Left (x=0):')
                    traverse(left, depth + 1, prefix + '  |   ')
                    tree_lines.append(f'{prefix}  |-- Right (x=1):')
                    traverse(right, depth + 1, prefix + '      ')
                else:
                    tree_lines.append(f'{prefix}  |-- Left  (x=0) -> Leaf {left - offset + 1}')
                    tree_lines.append(f'{prefix}  |-- Right (x=1) -> Leaf {right - offset + 1}')
            traverse(0, 0)
            tree_lines.append('--------------------------------\n')
        except Exception as e:
            pass
    lines.append('Pattern Format: ([left branching features], [right branching features])')
    global_x = globals().get('x', None)
    global_y = globals().get('y_k', None)
    labels = globals().get('KK', globals().get('K', None))
    bag_fn = globals().get('get_misclassification_bag', None)
    ord_fn = globals().get('get_misclassification', None)
    for i, leaf_patterns in enumerate(native_patterns):
        if not leaf_patterns:
            continue
        def eval_class(p, idx):
            if global_x is not None and global_y is not None and labels is not None:
                try:
                    fn = bag_fn if isinstance(p, tuple) else ord_fn
                    if fn:
                        res = fn(global_x, global_y, p, idx)
                        if res[1] > 0:
                            class_counts = np.sum(global_y[np.where(res[2])], axis=0)
                            return f' -> Class {labels[np.argmax(class_counts)]}'
                        return ' -> Class N/A (Empty)'
                except Exception as e:
                    pass
            return ''
        if isinstance(leaf_patterns, list):
            for p in leaf_patterns:
                lines.append(f'Leaf {i+1}: {p}{eval_class(p, i)}')
        else:
            p = leaf_patterns
            lines.append(f'Leaf {i+1}: {p}{eval_class(p, i)}')
    
    lines.extend(tree_lines)
    return '\n'.join(lines)

print(format_rules(inc_patterns))
sys.stdout = orig_stdout
f.close()
